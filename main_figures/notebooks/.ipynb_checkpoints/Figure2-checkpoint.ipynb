# %%
from scipy import stats
pd.set_option('mode.chained_assignment',  None)

# %% [markdown]
# ### Figure 2

# %% [markdown]
# Read data

# %%
files = ["../data/Figure2ab_Data_ru.csv", 
         "../data/Figure2c_Data.csv"]
dat = []
for f in files:
    sep = "\t" if f.endswith("tsv") else ","
    df = pd.read_csv(f, sep=sep)
    df = df.rename(columns = {c:c.replace("Boostrap", "Bootstrap") 
                              for c in df.columns if "Boos" in c})
    dat.append(df)   
    
#dat[1]["Distance"] = dat[0].Distance

# %%
coef = pd.read_csv("../data/Figure2c_Data.tsv",sep="\t")
coef = coef.iloc[::-1].reset_index(drop=True)

# %% [markdown]
# Plot figures

# %%
# Panel C
f,ax = plt.subplots()

ax.axvline(x=0, color="lightgray", linestyle="dashed")
colors = ["black", "gray", "lightgray"]

margins = [-0.1,0,0.1]
for i,t in enumerate(["All", "Macro", "Micro"]):
    color = f"C{i}" #colors[i]
    ax.scatter(coef[t], coef.index+margins[i], c=color, s=15, label=t)
    for y,r in coef.iterrows():
        ax.plot([r[f"{t}_075"], r[f"{t}_025"]], 
                [y+margins[i],y+margins[i]], c=color)

ax.legend()
ax.set_xlabel(r"$\beta$")
ax.set_yticks(coef.index)
labels = ["All PRDM9\nbinding sites", "CpG islands", "TSS", "CpG islands\nx\nTSS", "PRDM9\nx\n(CpGi or TSS)"]
ax.set_yticklabels(labels)
# Out:
# [Text(0, 0, 'PRDM9x(CpGI or TSS)'),
#  Text(0, 1, 'CpGIxTSS'),
#  Text(0, 2, 'TSS'),
#  Text(0, 3, 'CpG Islands'),
#  Text(0, 4, 'PRDM9 Binding Sites')]

# %%
mosaic = '''
AB
CD
'''
f, axs = plt.subplot_mosaic(mosaic,
                            figsize=[8,8])


# Panel A
idx = 0
ax = axs["A"]
tdf = dat[idx]
handles = []

palette = {"prdm9_all":"blue", 
           "promoters":"orange"}
x = "distance"
y = "norm_mean"
y_lw = "norm_low_ci"
y_hg = "norm_high_ci"

for feature, color in palette.items():
        
    df = tdf[tdf.kind==feature]
    norm = df[df.distance.between(8e3,10e3)]["mean"].mean()
    for p in ["mean", "low_ci", "high_ci"]:
        df[f"norm_{p}"] = np.where((df[p] < 1e9), df[p]/norm, df[p])
        
    sns.lineplot(data=df, 
                 x=x, y=y, 
                 c=color,                 
                 ax=ax,                                          
                 label=feature)
    
    handles.append(plt.Line2D([], [], 
                              color=color, 
                              label=feature))
    
    ax.fill_between(df[x], 
                    df[y_lw], 
                    df[y_hg], 
                    color=color, 
                    alpha=0.25)
    
    ax.axhline(y=1, 
               linestyle="dashed", 
               color="lightgray", 
               zorder=0)
    
    ax.set_xlabel("Distance to nearest feature (bps) for\nregions far from the other feature")
    ax.set_ylabel("Relative recombination rate")

ax.legend(handles = handles, title="Feature",
          frameon=True,
          labels = ["All PRDM9\nbinding sites", "Promoter-like\nfeatures"])

ax.set_ylim(bottom = 0)
# Panel B
idx = 1
ax = axs["B"]
tdf = dat[0]

paletteB = {"prdm9_all":"blue", "KmerZFs_11_0":"purple"}
sel_kmers = list(paletteB.keys())
label_dict = {"prdm9_all": "All PRDM9", "KmerZFs_11_0":"Shared 11-ZF"}#\nbinding sites
kmers = [c for c in tdf.kind.unique() if "prom" not in c]
kmer_colors = [c for i,c in enumerate(sns.color_palette("tab10", 11)) if i not in [0,4]]

i = 0
for k in kmers:
    if k not in paletteB:
        paletteB[k] = kmer_colors[i]
        i += 1

for feature, color in paletteB.items():
    
    df = tdf[tdf.kind==feature]
    norm = df[df.distance.between(8e3,10e3)]["mean"].mean()
    for p in ["mean", "low_ci", "high_ci"]:
        df[f"norm_{p}"] = np.where((df[p] < 1e9), df[p]/norm, df[p])

    sns.lineplot(data=df, 
                 x=x, y=y, 
                 c=color,                 
                 ax=ax,
                 alpha =1 if feature in sel_kmers else 0.15,
                 label=label_dict[feature] if feature in sel_kmers else "",
                 zorder=10 if feature in sel_kmers else 1)

    handles.append(plt.Line2D([], [], 
                              color=color, 
                              label=feature))

    ax.fill_between(df[x], 
                    df[y_lw], 
                    df[y_hg], 
                    color=color, 
                    alpha=0.25 if feature in sel_kmers else 0.07, 
                    zorder=10 if feature in sel_kmers else 1)

    ax.axhline(y=1, 
               linestyle="dashed", 
               color="lightgray", 
               zorder=0)

ax.legend(frameon=True, title="Binding site")
ax.set_xlabel("Distance to nearest PRDM9 binding site (bps) for\nregions far from promoter-like features")
ax.set_ylabel("Relative recombination rate")

# Panel C

ax = axs["C"]

ax.axvline(x=0, color="lightgray", linestyle="dashed")
colors = ["black", "gray", "lightgray"]

margins = [-0.1,0,0.1]
for i,t in enumerate(["All", "Macro", "Micro"]):
    print(coef.index+margins[i])
    color = f"C{i}" #colors[i]
    ax.scatter(coef[t], coef.index+margins[i], c=color, s=15, label=t)
    for y,r in coef.iterrows():
        ax.plot([r[f"{t}_075"], r[f"{t}_025"]], 
                [y+margins[i],y+margins[i]], c=color)

ax.legend()
ax.set_xlabel(r"$\beta$")
ax.set_yticks(coef.index)
ax.set_yticklabels(coef.Name)

# Panel D
idx = 2
ax = axs["D"]
df = dat[-1]
shuf = df[df.kind!="original"]
orig = df[df.kind=="original"]

spots = ["coldspots", "hotspots"]
labels = ["Overlap with PRDM9 binding sites\n(>10kb from CpG island)", 
          "Overlap with CpG islands\n(>10kb from a PRDM9 binding site)"]

palettes = {"prdm9_cond":{"hotspots":"purple", "coldspots":"gray"}}

for i,v in enumerate(["prdm9_cond"]):
    g = sns.histplot(data=shuf, x=v,
                     hue="spot", 
                     hue_order=spots,
                     palette = palettes[v],
                     element="step",stat="probability", 
                     common_norm=False,
                     bins = 17,
                     alpha = 0.1,
                     ax=ax)

    ax.legend(loc="upper right",
              labels=["Hotspots", "Coldspots"], 
              title="Region",
              frameon=True, 
              bbox_to_anchor=(.71, 1))

    for isp,sp in enumerate(spots):
        o = orig[orig.spot==sp][v].values[0]
        perc = stats.percentileofscore(shuf[v], o)
        ax.axvline(x=o, c=palettes[v][sp])

ax.set_xlim(right=0.17)
ax.set_xlabel("Fraction of regions far from promoter-like features\noverlapping a Shared 11-ZF binding site")
ax.set_ylabel("Proportion of shuffled regions")

panel_letters = ['A', 'B', 'C']

sns.despine()
plt.tight_layout()
# Out:
# Float64Index([-0.1, 0.9, 1.9, 2.9, 3.9], dtype='float64')
# RangeIndex(start=0, stop=5, step=1)
# Float64Index([0.1, 1.1, 2.1, 3.1, 4.1], dtype='float64')

# %%
f,axs = plt.subplots(1,3, figsize=[13,4.2])

# Panel A
idx = 0
ax = axs[idx]
tdf = dat[idx]
handles = []

palette = {"prdm9_all":"blue", 
           "promoters":"orange"}
x = "distance"
y = "norm_mean"
y_lw = "norm_low_ci"
y_hg = "norm_high_ci"

for feature, color in palette.items():
        
    df = tdf[tdf.kind==feature]
    norm = df[df.distance.between(8e3,10e3)]["mean"].mean()
    for p in ["mean", "low_ci", "high_ci"]:
        df[f"norm_{p}"] = np.where((df[p] < 1e9), df[p]/norm, df[p])
        
    sns.lineplot(data=df, 
                 x=x, y=y, 
                 c=color,                 
                 ax=ax,                                          
                 label=feature)
    
    handles.append(plt.Line2D([], [], 
                              color=color, 
                              label=feature))
    
    ax.fill_between(df[x], 
                    df[y_lw], 
                    df[y_hg], 
                    color=color, 
                    alpha=0.25)
    
    ax.axhline(y=1, 
               linestyle="dashed", 
               color="lightgray", 
               zorder=0)
    
    ax.set_xlabel("Distance to nearest feature (bps) for\nregions far from the other feature")
    ax.set_ylabel("Relative recombination rate")

ax.legend(handles = handles, title="Feature",
          frameon=True,
          labels = ["All PRDM9\nbinding sites", "Promoter-like\nfeatures"])

ax.set_ylim(bottom = 0)
# Panel B
idx = 1
ax = axs[idx]
tdf = dat[0]

paletteB = {"prdm9_all":"blue", "KmerZFs_11_0":"purple"}
sel_kmers = list(paletteB.keys())
label_dict = {"prdm9_all": "All PRDM9", "KmerZFs_11_0":"Shared 11-ZF"}#\nbinding sites
kmers = [c for c in tdf.kind.unique() if "prom" not in c]
kmer_colors = [c for i,c in enumerate(sns.color_palette("tab10", 11)) if i not in [0,4]]

i = 0
for k in kmers:
    if k not in paletteB:
        paletteB[k] = kmer_colors[i]
        i += 1

for feature, color in paletteB.items():
    
    df = tdf[tdf.kind==feature]
    norm = df[df.distance.between(8e3,10e3)]["mean"].mean()
    for p in ["mean", "low_ci", "high_ci"]:
        df[f"norm_{p}"] = np.where((df[p] < 1e9), df[p]/norm, df[p])

    sns.lineplot(data=df, 
                 x=x, y=y, 
                 c=color,                 
                 ax=ax,
                 alpha =1 if feature in sel_kmers else 0.15,
                 label=label_dict[feature] if feature in sel_kmers else "",
                 zorder=10 if feature in sel_kmers else 1)

    handles.append(plt.Line2D([], [], 
                              color=color, 
                              label=feature))

    ax.fill_between(df[x], 
                    df[y_lw], 
                    df[y_hg], 
                    color=color, 
                    alpha=0.25 if feature in sel_kmers else 0.07, 
                    zorder=10 if feature in sel_kmers else 1)

    ax.axhline(y=1, 
               linestyle="dashed", 
               color="lightgray", 
               zorder=0)

ax.legend(frameon=True, title="Binding site")
ax.set_xlabel("Distance to nearest PRDM9 binding site (bps) for\nregions far from promoter-like features")
ax.set_ylabel("Relative recombination rate")

# Panel C
idx = 2
ax = axs[idx]
df = dat[-1]
shuf = df[df.kind!="original"]
orig = df[df.kind=="original"]

spots = ["coldspots", "hotspots"]
labels = ["Overlap with PRDM9 binding sites\n(>10kb from CpG island)", 
          "Overlap with CpG islands\n(>10kb from a PRDM9 binding site)"]

palettes = {"prdm9_cond":{"hotspots":"purple", "coldspots":"gray"}}

for i,v in enumerate(["prdm9_cond"]):
    g = sns.histplot(data=shuf, x=v,
                     hue="spot", 
                     hue_order=spots,
                     palette = palettes[v],
                     element="step",stat="probability", 
                     common_norm=False,
                     bins = 17,
                     alpha = 0.1,
                     ax=ax)

    ax.legend(loc="upper right",
              labels=["Hotspots", "Coldspots"], 
              title="Region",
              frameon=True, 
              bbox_to_anchor=(.71, 1))

    for isp,sp in enumerate(spots):
        o = orig[orig.spot==sp][v].values[0]
        perc = stats.percentileofscore(shuf[v], o)
        ax.axvline(x=o, c=palettes[v][sp])

ax.set_xlim(right=0.17)
ax.set_xlabel("Fraction of regions far from promoter-like features\noverlapping a Shared 11-ZF binding site")
ax.set_ylabel("Proportion of shuffled regions")

panel_letters = ['A', 'B', 'C']

sns.despine()
plt.tight_layout()
#plt.savefig("../pdfs/Figure2_1MB.pdf")
#plt.savefig("../pdfs/Figure2_1MB.jpg", dpi=400)

# %%
f,axs = plt.subplots(1,2, figsize=[8,4], sharey=True)

# Panel A
idx = 0
tdf = dat[idx]
handles = []

palette = {"promoters":"orange", 
           "prdm9_all":"blue"}

labels = ["promoter-like feature", "PRDM9 binding site"]

x = "distance"
y = "norm_mean"
y_lw = "norm_low_ci"
y_hg = "norm_high_ci"

for i,(feature, color) in enumerate(palette.items()):
        
    ax = axs[i]
    df = tdf[tdf.kind==feature]
    norm = df[df.distance.between(8e3,10e3)]["mean"].mean()
    for p in ["mean", "low_ci", "high_ci"]:
        df[f"norm_{p}"] = np.where((df[p] < 1e9), df[p]/norm, df[p])
        
    sns.lineplot(data=df, 
                 x=x, y=y, 
                 c=color,                 
                 ax=ax)
    
    handles.append(plt.Line2D([], [], 
                              color=color))
    
    ax.fill_between(df[x], 
                    df[y_lw], 
                    df[y_hg], 
                    color=color, 
                    alpha=0.3)
    
    ax.axhline(y=1, 
               linestyle="dashed", 
               color="lightgray", 
               zorder=0)
    
    ax.set_xlabel(f"Distance to nearest {labels[i]}\n(positions >10kb away from a {labels[::-1][i]})")
    ax.set_ylabel("Relative recombination rate")
    
plt.tight_layout()
sns.despine()
plt.savefig("../pdfs/Figure2A_split_complabel.pdf")

# %%
frac = 44362000/1.6e9
heat = 13

# %%
(frac * heat) / ((frac * heat) + (1-frac))
# Out:
# 0.2704563616377095
